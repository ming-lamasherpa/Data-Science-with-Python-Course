# %% [markdown]
# ## Day-1 - Python class

# %%
# code are excutable line of python
print("this is my first code")
# Out:
# this is my first code

# %%
# first Program is Python
print("hello world")
# Out:
# hello world

# %%
# Data Analysis , AI and ML

# %%
#python
x=10
y=15
z=x+y
print("the sum is :",z)
# Out:
# the sum is : 25

# %% [markdown]
# ## Variable

# %% [markdown]
# #variables are places in computer's memory that hold / stores data, temporarily

# %%
##Data : any values given by the user into the computer (program)
##in python broadly we have two different type of data type
##a) fundamental DAta type
##most basic type of data ,they cannot be further simplified
##int,float,string
##b)Derived Data type
##data type made by combining one or more fundamental data types
##list,typle,set,dictionary,string,array

# %%
x=10 #DAta type

# %%
type(x)
# Out:
# int

# %%
y=-16.5
type(y)
# Out:
# float

# %%
z = '10.65'
type(z)
# Out:
# str

# %% [markdown]
# ## Write a program to store 10 and 11 in two dif var and print sum

# %%
x=10
y=11
z=x+y
print("The sum is",z)
# Out:
# The sum is 21

# %% [markdown]
# ## User Input

# %%
#input(): allows user to enter his\her values in to the program
a=input("enter first number")
a=float(a)
b=input("enter sec number")
b=float(b)
s=a*b
print("Product",s)
# Out:
# enter first number 12
# enter sec number 15
# Product 180.0

# %% [markdown]
# ## Question:ASk length,breadth,height with user and print the Volume ? ?

# %%
# Operators and Operatons

# %%
x=13
y=3
x/y
# Out:
# 4.333333333333333

# %%
#Float Division(//) (Returns the quotient part)
x//y
# Out:
# 4

# %%
#Modular Division (%) (returns the remainder)
x % y
# Out:
# 1

# %%
# Exponential 2 the power 8
2**8
# Out:
# 256

# %%
# Logical operators (and ,or,not)

# %%
x=10
y=20
x>10 and y>5
# Out:
# False

# %%
x=10
y=20
x<5 or y>10
# Out:
# True

# %%
not(x<5 or y>10)
# Out:
# False
